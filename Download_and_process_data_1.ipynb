# %%
import pandas as pd
import os
from collections import Counter, defaultdict
from scipy.stats import scoreatpercentile
import warnings
import numpy as np
from statsmodels.stats import multitest
import venn


from ast import literal_eval
import matplotlib
import numpy
import pandas
import random

import matplotlib.pyplot as plt
# %matplotlib inline


import scipy
from scipy.stats import rankdata
from scipy.stats import norm
import pickle
from copy import deepcopy
import csv

from scipy.stats import rankdata
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from itertools import chain, combinations
import time as timemodule
import ast
from copy import copy

from scipy.stats import zscore
from ast import literal_eval
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import ast
import gc
from pyteomics import fasta, parser, mzml
from os import path, listdir
import itertools

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn import metrics

import math
import statistics

from sklearn import preprocessing
from scipy import optimize
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from statistics import stdev
from scipy.stats import anderson


pd.set_option('display.max_columns', 50)

# %matplotlib inline

# %%
# Enter here path to project directory
infolder = "/home/sych/tpp_directory/"

# %%
# Create project directory if it is not exist
if not os.path.isdir(infolder):
    os.makedirs(infolder)

# %%
# Move to the project directory
# %cd $infolder
# %pwd

# %%
# Download feature files from ProteomeXchange

# !wget -b ftp://ftp.pride.ebi.ac.uk/pride/archive/projects/PXD051712/*.raw

# %%
# For the next step, you should install ThermoRawFileParser (https://github.com/compomics/ThermoRawFileParser)

# %%
# Run ThermoRawFileParser for all raw files with an option to extract only MS1 spectra

for fn in os.listdir(infolder):
    if fn.endswith('.raw'):
        infile1 = os.path.join(infolder, fn)
        # !ThermoRawFileParser -i $infile1 -L 1 -o $infolder

# %%
# (Optional)
# Remove all raw files which were already converted

# for fn in os.listdir(infolder):
#     if fn.endswith('.mzML'):
#         mzmlfile = os.path.join(infolder, fn)
#         rawname = mzmlfile.replace('.mzML', '.raw')
#         if os.path.getsize(mzmlfile) > 78502:
#             if os.path.exists(rawname):
#                 os.remove(rawname)
#         else:
#             print('small size', mzmlfile, os.path.getsize(mzmlfile))

# %%
# For the next step, you should install biosaur2 (https://github.com/markmipt/biosaur2)
# !pip install biosaur2

# %%
# Run biosaur2 for all mzML files to extract peptide isotope clusters.

for fn in os.listdir(infolder):
    if fn.endswith('.mzML'):
        mzmlname = os.path.join(infolder, fn)
        # !biosaur2 $mzmlname -minlh 1

# %%
# (Optional)
# Remove all mzML files which were already converted

# for fn in os.listdir(infolder):
#     if fn.endswith('.features.tsv'):
#         ftrfile = os.path.join(infolder, fn)
#         mzmlfile = ftrfile.replace('.features.tsv', '.mzML')
#         if os.path.getsize(ftrfile) > 1000:
#             if os.path.exists(mzmlfile):
#                 os.remove(mzmlfile)

# %%
# For the next step, you should install ms1searchpy (https://github.com/markmipt/ms1searchpy)
# !pip install ms1searchpy

# %%
# For the next step, you should install DeepLC (https://github.com/compomics/DeepLC)
# The recommended version is the clone available at https://github.com/markmipt/DeepLC
# The latest official DeepLC versions should work too, but ms1searchpy processing time will be much longer
# !pip install https://github.com/markmipt/DeepLC/archive/refs/heads/alternative_best_model.zip

# %%
# For the next step, you should put protein fasta database into working directory
# !wget -b ftp://ftp.pride.ebi.ac.uk/pride/archive/projects/PXD051712/*shuffled.fasta

# %%
# Run ms1searchpy for all *features.tsv files generated by biosaur2

infasta = os.path.join(infolder, 'sprot_human_shuffled.fasta')
for fn in os.listdir(infolder):
    if fn.endswith('.features.tsv'):
        ftrfile = os.path.join(infolder, fn)
        protfile = ftrfile.replace('.features.tsv', '.features_proteins.tsv')
        if not os.path.exists(protfile):
            # !ms1searchpy $ftrfile -d $infasta  -sc 1 -i 2 -nproc 8 -mc 0 -cmin 1 -ptol 8 -fdr 1 -ts 2 -ml 1 -deeplc 1 -lmin 7 -mcalib 0 -deeplc_library /tmp/deeplc345.lib

# %%
# Download .csv file from Github
# https://github.com/ProstoSych/TPP_visualise/blob/main/11052022_TPP_exp.csv

# %%
# For the next step, you should put sample list for Treatment and Controls samples into working directory
# The sample list is placed along this notebook on the github (Astral_Sample.tsv) Download .csv file from Github
# https://github.com/ProstoSych/TPP_visualise/blob/main/11052022_TPP_exp.csv

# %%
ms1folder = infolder
path_to_fasta = os.path.join(ms1folder, 'sprot_human_160320_shuffled.fasta')

df1 = pd.read_csv(os.path.join(ms1folder, '11052022_TPP_exp.csv'))
df1 = df1[df1['File Name'].apply(lambda x: x.startswith('QEHFX'))]
df1 = df1[df1['Sample ID'].apply(lambda x: x.endswith('1 ug'))]

df1 = df1[df1['File Name'].apply(lambda x: x not in ['QEHFX_JB_000259', 'QEHFX_JB_000259_2', 'QEHFX_JB_000299_1', 'QEHFX_JB_000272_1', 'QEHFX_JB_000240_old'])]

allowed_filenames = set(df1['File Name'])

for fn in listdir(ms1folder):
    if fn.endswith('_proteins.tsv'):
        f_name = fn.replace('.features_proteins.tsv', '')
        if f_name in allowed_filenames:
            df0 = pd.read_table(path.join(ms1folder, fn))
            df1.loc[df1['File Name'] == f_name, 'MS1 results, 5% FDR'] = df0.shape[0]

# %%
df1['timing'] = df1['Sample ID'].apply(lambda x: x.strip().split('_')[1])
df1['sample'] = df1['Sample ID'].apply(lambda x: x.strip().split('_')[2][0])
df1['replicate'] = df1['Sample ID'].apply(lambda x: int(x.strip().split('_')[2][-1]))

# %%
# Out:
#            File Name          Sample ID                    Path  \
# 12   QEHFX_JB_000240  TPP_59C_K1_1 1 ug  C:\Xcalibur\data\Julia
# 13   QEHFX_JB_000241  TPP_59C_K2_1 1 ug  C:\Xcalibur\data\Julia
# 14   QEHFX_JB_000242  TPP_59C_K3_1 1 ug  C:\Xcalibur\data\Julia
# 15   QEHFX_JB_000243  TPP_59C_K4_1 1 ug  C:\Xcalibur\data\Julia
# 16   QEHFX_JB_000244  TPP_59C_K5_1 1 ug  C:\Xcalibur\data\Julia
# ..               ...                ...                     ...
# 133  QEHFX_JB_000335  TPP_37C_T1_1 1 ug  C:\Xcalibur\data\Julia
# 134  QEHFX_JB_000336  TPP_37C_T2_1 1 ug  C:\Xcalibur\data\Julia
# 135  QEHFX_JB_000337  TPP_37C_T3_1 1 ug  C:\Xcalibur\data\Julia
# 136  QEHFX_JB_000338  TPP_37C_T4_1 1 ug  C:\Xcalibur\data\Julia
# 137  QEHFX_JB_000339  TPP_37C_T5_1 1 ug  C:\Xcalibur\data\Julia
#
#                                      Instrument Method  Process Method  \
# 12   C:\Xcalibur\data\Zgoda\110522_JB\MS1_late_valv...             NaN
# 13   C:\Xcalibur\data\Zgoda\110522_JB\MS1_late_valv...             NaN
# 14   C:\Xcalibur\data\Zgoda\110522_JB\MS1_late_valv...             NaN
# 15   C:\Xcalibur\data\Zgoda\110522_JB\MS1_late_valv...             NaN
# 16   C:\Xcalibur\data\Zgoda\110522_JB\MS1_late_valv...             NaN
# ..                                                 ...             ...
# 133  C:\Xcalibur\data\Zgoda\110522_JB\MS1_late_valv...             NaN
# 134  C:\Xcalibur\data\Zgoda\110522_JB\MS1_late_valv...             NaN
# 135  C:\Xcalibur\data\Zgoda\110522_JB\MS1_late_valv...             NaN
# 136  C:\Xcalibur\data\Zgoda\110522_JB\MS1_late_valv...             NaN
# 137  C:\Xcalibur\data\Zgoda\110522_JB\MS1_late_valv...             NaN
#
#     Position  Inj Vol  MS1 results, 5% FDR timing sample  replicate
# 12       GA2      1.5               1135.0    59C      K          1
# 13       GA3      1.5                969.0    59C      K          2
# 14       GA4      1.5               1110.0    59C      K          3
# 15       GA5      1.5               1157.0    59C      K          4
# 16       GA6      1.5               1125.0    59C      K          5
# ..       ...      ...                  ...    ...    ...        ...
# 133      GC1      1.5               1312.0    37C      T          1
# 134      GC2      1.5               1284.0    37C      T          2
# 135      GC3      1.5               1395.0    37C      T          3
# 136      GC4      1.5               1163.0    37C      T          4
# 137      GC5      1.5               1302.0    37C      T          5
#
# [100 rows x 11 columns]

# %%
f_dict_map = {}

for fname, sname, ttime in df1[['File Name', 'sample', 'timing']].values:
    f_dict_map[fname] = (sname, ttime)

# %%
# Out:
# (array([ 3.,  7.,  2.,  7.,  6., 11., 14., 23., 20.,  7.]),
#  array([ 762. ,  825.3,  888.6,  951.9, 1015.2, 1078.5, 1141.8, 1205.1,
#         1268.4, 1331.7, 1395. ]),
#  <BarContainer object of 10 artists>)

# %%
set(df1['timing'])
# Out:
# {'37C', '41C', '44C', '47C', '50C', '53C', '56C', '59C', '63C', '67C'}

# %%
set(df1['sample'])
# Out:
# {'K', 'T'}

# %%
all_timings = ['37C', '41C', '44C', '47C', '50C', '53C', '56C', '59C', '63C', '67C']

resdict = {}
for sname in ['K', 'T', ]:
    resdict[sname] = defaultdict(list)
for sname, ttime, val in df1[['sample', 'timing', 'MS1 results, 5% FDR']].values:
    resdict[sname][ttime].append(val)

# %%
# Out:
# {'K': defaultdict(list,
#              {'59C': [1135.0, 969.0, 1110.0, 1157.0, 1125.0],
#               '56C': [862.0, 762.0, 1078.0, 1031.0, 1191.0],
#               '53C': [1212.0, 1161.0, 1121.0, 972.0, 1246.0],
#               '67C': [790.0, 1138.0, 965.0, 1100.0, 1049.0],
#               '44C': [1349.0, 1267.0, 1362.0, 1227.0, 1258.0],
#               '50C': [1171.0, 870.0, 823.0, 1229.0, 1272.0],
#               '41C': [1272.0, 1247.0, 1304.0, 1316.0, 1305.0],
#               '47C': [1083.0, 975.0, 1262.0, 1020.0, 1266.0],
#               '63C': [970.0, 883.0, 829.0, 1122.0, 1160.0],
#               '37C': [1352.0, 1306.0, 1294.0, 1263.0, 1167.0]}),
#  'T': defaultdict(list,
#              {'59C': [1214.0, 1173.0, 1189.0, 1175.0, 1234.0],
#               '56C': [1108.0, 1248.0, 1196.0, 908.0, 1216.0],
#               '53C': [1143.0, 1241.0, 1209.0, 873.0, 981.0],
#               '67C': [1149.0, 841.0, 1034.0, 887.0, 1213.0],
#               '44C': [1226.0, 1313.0, 1311.0, 1178.0, 1287.0],
#               '50C': [1282.0, 1036.0, 961.0, 1324.0, 1222.0],
#               '41C': [1343.0, 1314.0, 1296.0, 1122.0, 1392.0],
#               '47C': [1306.0, 1267.0, 1301.0, 1285.0, 1371.0],
#               '63C': [1111.0, 925.0, 1221.0, 1237.0, 1243.0],
#               '37C': [1312.0, 1284.0, 1395.0, 1163.0, 1302.0]})}

# %%
all_conditions = []
all_conditions2 = []
for k, v in resdict.items():
    for kk in v.keys():
        if k == 'T':
            all_conditions.append((k, kk))
        all_conditions2.append((k, kk))

# %%
# Out:
# ([('T', '59C'),
#   ('T', '56C'),
#   ('T', '53C'),
#   ('T', '67C'),
#   ('T', '44C'),
#   ('T', '50C'),
#   ('T', '41C'),
#   ('T', '47C'),
#   ('T', '63C'),
#   ('T', '37C')],
#  [('K', '59C'),
#   ('K', '56C'),
#   ('K', '53C'),
#   ('K', '67C'),
#   ('K', '44C'),
#   ('K', '50C'),
#   ('K', '41C'),
#   ('K', '47C'),
#   ('K', '63C'),
#   ('K', '37C'),
#   ('T', '59C'),
#   ('T', '56C'),
#   ('T', '53C'),
#   ('T', '67C'),
#   ('T', '44C'),
#   ('T', '50C'),
#   ('T', '41C'),
#   ('T', '47C'),
#   ('T', '63C'),
#   ('T', '37C')])

# %%
# Run DirectMS1Quant

s_files_dict = defaultdict(list)

for fn in listdir(ms1folder):
    if fn.endswith('_proteins_full.tsv'):
        f_name = fn.replace('.features_proteins_full.tsv', '')
        if f_name in f_dict_map:
            s_files_dict[f_dict_map[f_name]].append(path.join(ms1folder, fn))
        
for temp in ['T', 'K']:
    for tt in all_timings[1:]:
        i1 = (temp, '37C')
        i2 = (temp, tt)
        print(i1, i2)
        
        S_first_list = ' '.join(s_files_dict[i1])
        S_second_list = ' '.join(s_files_dict[i2])
        out_name = path.join(ms1folder, 'fulldirectms1quant_out_%s_vs_%s' % (''.join(list(i1)), ''.join(list(i2))))
        # !/home/sych/venv/bin/directms1quant\
        -S1 $S_first_list\
        -S2 $S_second_list -out $out_name -fold_change 2 -d\
        $path_to_fasta -min_samples 4 -qval 0.05 -all_pfms

# %%
def sort_columns(x):
    v = 0
    if 'T' in x:
        v += 1000
        
    x_time = x.replace('T', '').replace('K', '').replace('C', '')
        
    koef = float(x_time)
        
    v += koef
        
    return v

# %%
lbls = [''.join(z) for z in all_conditions]
lbls = sorted(lbls, key=sort_columns)
# Out:
# ['T37C',
#  'T41C',
#  'T44C',
#  'T47C',
#  'T50C',
#  'T53C',
#  'T56C',
#  'T59C',
#  'T63C',
#  'T67C']

# %%
lbls2 = [''.join(z) for z in all_conditions2]
lbls2 = sorted(lbls2, key=sort_columns)
# Out:
# ['K37C',
#  'K41C',
#  'K44C',
#  'K47C',
#  'K50C',
#  'K53C',
#  'K56C',
#  'K59C',
#  'K63C',
#  'K67C',
#  'T37C',
#  'T41C',
#  'T44C',
#  'T47C',
#  'T50C',
#  'T53C',
#  'T56C',
#  'T59C',
#  'T63C',
#  'T67C']

# %%
df_prots = False
all_prots = set()

for temp in ['T', 'K']:
    for tt in all_timings[1:]:
        i1 = (temp, '37C')
        i2 = (temp, tt)
        out_name = path.join(ms1folder, 'fulldirectms1quant_out_%s_vs_%s.tsv' % (''.join(list(i1)), ''.join(list(i2))))
        if os.path.isfile(out_name):
            df0 = pd.read_table(out_name)
            all_prots.update(set(df0['dbname']))
        
        


for temp in ['T', 'K']:
    for tt in all_timings[1:]:
        i1 = (temp, '37C')
        i2 = (temp, tt)
        out_name = path.join(ms1folder, 'fulldirectms1quant_out_%s_vs_%s.tsv' % (''.join(list(i1)), ''.join(list(i2))))
        if os.path.isfile(out_name):
            df0_full = pd.read_table(out_name.replace('.tsv', '_quant_full.tsv'))
            df0_full = df0_full[df0_full['dbname'].apply(lambda x: x in all_prots)]

            lbl_c = ''.join(list(i2))

 
            df0_full.loc[:, 'log2FoldChange(S2/S1)'] = df0_full.loc[:, 'log2FoldChange(S2/S1) using all peptides']

            df0_full = df0_full[['dbname', 'log2FoldChange(S2/S1)', 'BH_pass', 'score']]
            df0_full = df0_full.rename(columns={'log2FoldChange(S2/S1)': lbl_c, 'BH_pass': 'BH_pass_'+lbl_c})

            if df_prots is False:
                df_prots = df0_full
            else:
                df_prots = df_prots.merge(df0_full, on='dbname', how='outer')
                df_prots['score'] = df_prots['score_x'] + df_prots['score_y']
                df_prots = df_prots.drop(columns=['score_x', 'score_y'])
                


df_prots['K37C'] = 0.0
df_prots['BH_pass_T37C'] = True            
df_prots['T37C'] = 0.0
df_prots['BH_pass_K37C'] = True            
            
cc_BH = [cc for cc in df_prots.columns if 'BH_pass' in cc]

df_prots['score'] = df_prots[cc_BH].sum(axis=1)

df_prots = df_prots.sort_values(by='score', ascending=False)

# %%
resdict = {}
resdict2 = {}
for z in df_prots[['dbname'] + [lbl for lbl in lbls2 if lbl in df_prots.columns]].values:
    resdict[z[0]] = z[1:]
    
    
for z in df_prots[['dbname'] + ['BH_pass_'+lbl for lbl in lbls2 if lbl in df_prots.columns]].values:
    resdict2[z[0]] = [(resdict[z[0]][idx] if cc is True else 0) for idx, cc in enumerate(z[1:])]

# %%
plt.close('all')

# %%
def func(x, a,b):
    x=np.array(x)
    return (1/(1+np.exp(abs(a)-((abs(a)*b)/x))))

# %%
def func(x, a,b):
    x=np.array(x)
    return 1/(1+np.exp(a-((a*b)/x)))

names=[]
coefsTT = pd.DataFrame(columns=['l', 't', 'k'])                   
coefsCC = pd.DataFrame(columns=['a', 'b'])
norm_flag = 1

for dbname in list(resdict.keys()):
#     if dbname in p1set:
        all_y = defaultdict(list)
        all_y2 = defaultdict(list)
        all_x = defaultdict(list)
        all_x2 = defaultdict(list)                                                      

        y_val_max = 0
        y_val_min = 0                                                                #КОД МАРКА

        for lbl, yval, yval2 in zip(lbls2, resdict[dbname], resdict2[dbname]):

     

            sample = ('C' if 'C' in lbl else 'T')
            timing = float(lbl.replace('T', '').replace('C', '').replace('C', ''))

            all_x[sample].append(timing + 273)
            all_y[sample].append(yval)

            if y_val_max < yval:
                y_val_max = yval
            if y_val_min > yval:
                y_val_min = yval


            if yval2 != 0:
                all_x2[sample].append(timing+273)
                all_y2[sample].append(yval2)

        if 1:                                                        
            for sample in ['C']:
                l2 = (2 ** (np.array(all_y[sample])))                 
                y1 = (l2 - l2.min())/(l2.max() - l2.min())

                try:
                    popt2, pcov2 = optimize.curve_fit(func, np.array(all_x[sample]), 
                                                      y1, p0=[200, 320], bounds=([0, 298], [600, 350]),
                                                      method='trf', maxfev = 10000000)
                    perr2 = np.sqrt(np.diag(pcov2))
                    coefsCC=pd.concat([coefsCC, pd.DataFrame([{'dbname': dbname, 'a': popt2[0], 'b': popt2[1],
                                                               'y_val': y1, 'y_val_without': l2,
                                                               'perr_a': perr2[0], 'perr_b': perr2[1]}])], 
                                      ignore_index=True)
                except:
                    print(f'не зафиттил контроль {dbname}, l2 = {l2}, y1 = {y1}')

            for sample in ['T']:
                def func2(x, b, a=popt2[0]):
                    x=np.array(x)
                    return (1/(1+np.exp(abs(a)-((abs(a)*b)/x))))

                def func_new(x, l, t, k, a=popt2[0], b=popt2[1]):
                    x = np.array(x)
                    return (((1 - k) / (1 + np.exp((a - (a * b) / x)))) + ((k) / (1 + np.exp((l - (b * l) / x - (t * l) / x)))))

                def regularized_func(x, l, t, k, a, b, lambd=0.001):
                    model = (((1 - k) / (1 + np.exp((a - (a * b) / x)))) + ((k) / (1 + np.exp((l - (b * l) / x - (t * l) / x)))))
                    penalty = lambd * (abs(t))+ 0.0001*(abs(l-a))
                    return model + penalty

                loh1 = (2 ** (np.array(all_y[sample])))                 
                y = (loh1 - loh1.min())/(loh1.max() - loh1.min())

                try:
                    popt4, pcov4 = optimize.curve_fit(func2, np.array(all_x[sample]), y,
                                                      p0=[320], bounds=([298], [350]),
                                                      method='trf', maxfev = 10000000)
                    popt8, pcov8 = optimize.curve_fit(func_new,
                                                      np.array(all_x[sample]), y,
                                                      p0=[popt2[0], popt4[0] - popt2[1], 0], bounds=([0, -30, 0], [600, 20, 1]),
                                                      method='trf', maxfev = 10000000)
                    y2_fit_treatment8 = func_new(np.array(all_x[sample]), *popt8, *popt2)

                    popt9, pcov9 = optimize.curve_fit(func_new, np.array(all_x[sample]), y,
                                                      p0=[popt2[0], popt4[0] - popt2[1], 0.5], bounds=([0, -30, 0], [600, 20, 1]),
                                                      method='trf', maxfev = 10000000)
                    y2_fit_treatment9 = func_new(np.array(all_x[sample]), *popt9, *popt2)

                    popt10, pcov10 = optimize.curve_fit(func_new, np.array(all_x[sample]), y,
                                                      p0=[popt2[0], popt4[0] - popt2[1], 1], bounds=([0, -30, 0], [600, 20, 1]),
                                                      method='trf', maxfev = 10000000)
                    y2_fit_treatment10 = func_new(np.array(all_x[sample]), *popt10, *popt2)
                    
                    
                    
                    popt5, pcov5 = optimize.curve_fit(lambda x, l, t, k, a=popt2[0], b=popt2[1]: regularized_func(x, l, t, k, a, b,),
                                                      np.array(all_x[sample]), y,
                                                      p0=[popt2[0], popt4[0] - popt2[1], 0], bounds=([0, -30, 0], [600, 20, 1]),
                                                      method='trf', maxfev = 10000000)
                    y2_fit_treatment5 = func_new(np.array(all_x[sample]), *popt5, *popt2)

                    popt6, pcov6 = optimize.curve_fit(lambda x, l, t, k, a=popt2[0], b=popt2[1]: regularized_func(x, l, t, k, a, b,),
                                                      np.array(all_x[sample]), y,
                                                      p0=[popt2[0], popt4[0] - popt2[1], 0.5], bounds=([0, -30, 0], [600, 30, 1]),
                                                      method='trf', maxfev = 10000000)
                    y2_fit_treatment6 = func_new(np.array(all_x[sample]), *popt6, *popt2)

                    popt7, pcov7 = optimize.curve_fit(lambda x, l, t, k, a=popt2[0], b=popt2[1]: regularized_func(x, l, t, k, a, b,),
                                                      np.array(all_x[sample]), y,
                                                      p0=[popt2[0], popt4[0] - popt2[1], 1], bounds=([0, -30, 0], [600, 30, 1]),
                                                      method='trf', maxfev = 10000000)
                    y2_fit_treatment7 = func_new(np.array(all_x[sample]), *popt7, *popt2)

                    r2_5 = r2_score(y2_fit_treatment5, y)
                    r2_6 = r2_score(y2_fit_treatment6, y)
                    r2_7 = r2_score(y2_fit_treatment7, y)
                    r2_8 = r2_score(y2_fit_treatment8, y)
                    r2_9 = r2_score(y2_fit_treatment9, y)
                    r2_10 = r2_score(y2_fit_treatment10, y)

                    if popt8[2] <=0.2 and popt9[2] <=0.2 and popt10[2] <=0.2:
                    
                        r_list = [r2_5, r2_6, r2_7]
                        r_min = max(r_list)

                        if r_min == r2_5:
                            popt = popt5
                            y2_fit_treatment = y2_fit_treatment5
                            pcov = pcov5
                        elif r_min == r2_6:
                            popt = popt6
                            y2_fit_treatment = y2_fit_treatment6
                            pcov = pcov6
                        else:
                            popt = popt7
                            y2_fit_treatment = y2_fit_treatment7
                            pcov = pcov7
                    else:
                    
                        r_list = [r2_8, r2_9, r2_10]
                        r_min = max(r_list)

                        if r_min == r2_8:
                            popt = popt8
                            y2_fit_treatment = y2_fit_treatment8
                            pcov = pcov8
                        elif r_min == r2_9:
                            popt = popt9
                            y2_fit_treatment = y2_fit_treatment9
                            pcov = pcov9
                        else:
                            popt = popt10
                            y2_fit_treatment = y2_fit_treatment10
                            pcov = pcov10

                    perr = np.sqrt(np.diag(pcov))
                    coefsTT = pd.concat([coefsTT, pd.DataFrame([{'dbname': dbname, 'l': popt[0], 
                                                                 't': popt[1], 'k': popt[2], 'y_val': y,
                                                                 'y_val_without': loh1,
                                                                 'b_K': popt4[0], 'diff_control': popt4[0] - popt2[1]}])], 
                                         ignore_index=True)


                except:
                    print(f'не зафиттил {dbname}, loh1 = {loh1}, y = {y}')
# Out:
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],
# /tmp/ipykernel_85210/494962645.py:59: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsCC=coefsCC.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
# /tmp/ipykernel_85210/494962645.py:89: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   coefsTT=coefsTT.append({'dbname': dbname, 'l':popt[0],

# %%
#Finding R^2 and k

difff = coefsTT.merge(coefsCC, how='inner', on='dbname', suffixes=('_T', '_C'))

x_difT=[]
for i in range(len(difff)):
    x_timedT=[]
    for j in range(len(all_x[sample])):
        x_timedT.append(all_x[sample][j])
    x_difT.append(x_timedT)

#########
#########

qu_difT=[]
for i in range(len(difff)):
    qu_timedT=[]
    for j in range(len(all_x[sample])):
        qu_timedT.append(func_new(all_x[sample][j], difff['l'][i], difff['t'][i],
                                  difff['k'][i], difff['a'][i], difff['b'][i]))

    qu_difT.append(qu_timedT)
    
qu_difTC=[]
for i in range(len(difff)):
    qu_timedTC=[]
    for j in range(len(all_x[sample])):
        qu_timedTC.append(func(all_x[sample][j], difff['a'][i], difff['b_K'][i]))
        
    qu_difTC.append(qu_timedTC)
    
qu_difC=[]
for i in range(len(difff)):
    qu_timedC=[]
    for j in range(len(all_x[sample])):
        qu_timedC.append(func(all_x[sample][j], difff['a'][i], difff['b'][i]))
        
    qu_difC.append(qu_timedC)
        
#########
#########

difff['x_val'] = x_difT
difff['func_val_T'] = qu_difT
difff['func_val_C'] = qu_difC
difff['func_val_TC'] = qu_difTC

#######
#######
r2_T=[]
r2_C =[]
r2_TC = []
for i in range(len(difff)):
    r2_T.append(r2_score(list(difff['y_val_T'][i]), list(difff['func_val_T'][i])))
    r2_C.append(r2_score(list(difff['y_val_C'][i]), list(difff['func_val_C'][i])))
    r2_TC.append(r2_score(list(difff['y_val_T'][i]), list(difff['func_val_TC'][i])))


difff['r2_T'] = r2_T
difff['r2_C'] = r2_C
difff['r2_TC'] = r2_TC
difff['r2'] = (difff['r2_T']+difff['r2_C'])/2

# ########
# ########

difff['difference'] = difff['t']

#########

#########

difff = difff.sort_values(['difference'])
difff['nicer3']=difff.apply(lambda x: x['r2_TC']>0.8, axis=1)
difff5=difff[difff['nicer3']]

difff['nicer2']=difff.apply(lambda x: round(x['r2_T'],1)>=0.8, axis=1)
difff['nicer']=difff.apply(lambda x: round(x['r2_C'],1)>=0.8, axis=1)
difff=difff[difff['nicer']]
difff=difff[difff['nicer2']]

# %%
np.std(difff5['diff_control'])
kst2 = np.array([])
for k in np.arange(2.5, 5, 0.1):
    prob_outside = 2 * norm.sf(k)  
    expected_outliers = prob_outside * len(difff)
    if expected_outliers<1:
        kst2 = np.append(kst2, k)
    print(f"{k} sigma: {expected_outliers} выбросов")
# Out:
#               l          t         k                 dbname  \
# 153  364.346643 -13.899683  0.625913   sp|Q96RP9|EFGM_HUMAN
# 174  394.159907 -13.842468  0.691703   sp|P50583|AP4A_HUMAN
# 80   600.000000 -11.318728  0.595597   sp|P49736|MCM2_HUMAN
# 95    87.274597 -10.780980  0.908626   sp|P33991|MCM4_HUMAN
# 201  111.036039  -9.467894  0.859799   sp|P61163|ACTZ_HUMAN
# ..          ...        ...       ...                    ...
# 236  600.000000   7.856104  0.699959   sp|P06396|GELS_HUMAN
# 235  600.000000   8.771168  0.709397   sp|O15305|PMM2_HUMAN
# 9    599.999997   9.570861  0.813597  sp|Q14166|TTL12_HUMAN
# 72   600.000000  15.080958  0.799427   sp|Q14376|GALE_HUMAN
# 131  256.337701  15.117787  0.506678    sp|P49327|FAS_HUMAN
#
#                                                y_val_T  \
# 153  [1.0, 1.0, 0.9828379796561223, 0.9812923488143...
# 174  [1.0, 0.9979073602857429, 0.9401583734435723, ...
# 80   [1.0, 1.0, 0.9856244279336307, 1.0, 0.47341796...
# 95   [1.0, 1.0, 1.0, 0.9537451977108128, 0.56562952...
# 201  [1.0, 0.9771308427176877, 0.9723667439827242, ...
# ..                                                 ...
# 236  [1.0, 1.0, 1.0, 1.0, 0.6131677998514223, 0.803...
# 235  [1.0, 1.0, 0.9944125983694744, 1.0, 0.92257998...
# 9    [1.0, 1.0, 1.0, 0.9504283321196139, 0.82797769...
# 72   [1.0, 0.9998617394747404, 0.9918165316713974, ...
# 131  [1.0, 1.0, 1.0, 1.0, 0.543640788556485, 0.7093...
#
#                                        y_val_without_T       perr_l    perr_t  \
# 153  [0.0, 0.0029077523520722, -0.0392447943691902,...   371.247729  0.532255
# 174  [0.0, -0.0052583969843961, -0.1503703798039538...   748.049358  0.781315
# 80   [0.0, 0.002521507609246, -0.0269661687404401, ...   246.879502  0.470383
# 95   [0.0, 0.0602621357476125, 0.0320530937130969, ...    34.584717  2.468375
# 201  [0.0, -0.042479711470378, -0.0513290773293539,...    40.270916  1.847063
# ..                                                 ...          ...       ...
# 236  [0.0, 0.0726657951186413, 0.1016051590709561, ...  3325.313065  0.633250
# 235  [0.0, 0.0306013039235668, -0.0489243984796704,...   212.359018  0.577624
# 9    [0.0, 0.0762689106596965, 0.025509511223006, -...   159.768843  0.404149
# 72   [0.0, -0.0012106366212961, -0.0716560741341685...   405.080264  0.920941
# 131  [0.0, 0.0766851959652226, 0.0193025064279881, ...   260.840454  1.258899
#
#        perr_k           a  ...  \
# 153  0.052482  544.324580  ...
# 174  0.089713  549.286265  ...
# 80   0.020449  423.835429  ...
# 95   0.209941  567.347630  ...
# 201  0.197488  187.861746  ...
# ..        ...         ...  ...
# 236  0.114957   64.047836  ...
# 235  0.021925  135.095365  ...
# 9    0.033767  159.841795  ...
# 72   0.019006  170.570735  ...
# 131  0.065009  139.312831  ...
#
#                                                  x_val  \
# 153  [310.0, 314.0, 317.0, 320.0, 323.0, 326.0, 329...
# 174  [310.0, 314.0, 317.0, 320.0, 323.0, 326.0, 329...
# 80   [310.0, 314.0, 317.0, 320.0, 323.0, 326.0, 329...
# 95   [310.0, 314.0, 317.0, 320.0, 323.0, 326.0, 329...
# 201  [310.0, 314.0, 317.0, 320.0, 323.0, 326.0, 329...
# ..                                                 ...
# 236  [310.0, 314.0, 317.0, 320.0, 323.0, 326.0, 329...
# 235  [310.0, 314.0, 317.0, 320.0, 323.0, 326.0, 329...
# 9    [310.0, 314.0, 317.0, 320.0, 323.0, 326.0, 329...
# 72   [310.0, 314.0, 317.0, 320.0, 323.0, 326.0, 329...
# 131  [310.0, 314.0, 317.0, 320.0, 323.0, 326.0, 329...
#
#                                             func_val_T  \
# 153  [0.9999998448696517, 0.9999804768334775, 0.999...
# 174  [0.9999999579430608, 0.9999921220529634, 0.999...
# 80   [0.9999999999450204, 0.9999998460298432, 0.999...
# 95   [0.9903619643842932, 0.9696743961789178, 0.931...
# 201  [0.9969169110663058, 0.9865373304221212, 0.961...
# ..                                                 ...
# 236  [0.9722767244551658, 0.9425144545064463, 0.908...
# 235  [0.9999184692750496, 0.9994949460411835, 0.998...
# 9    [0.9993572535913442, 0.9948358556203956, 0.978...
# 72   [0.9997633237996002, 0.9977574278139337, 0.988...
# 131  [0.9972696050610662, 0.9832844272820578, 0.941...
#
#                                             func_val_K      r2_T      r2_K  \
# 153  [1.0, 1.0, 0.9999999999999984, 0.9999999999996...  0.955654  0.920122
# 174  [1.0, 1.0, 0.9999999999999989, 0.9999999999997...  0.887962  0.876334
# 80   [0.9999999999999845, 0.9999999999948537, 0.999...  0.994767  0.963998
# 95   [1.0, 1.0, 0.9999999999999996, 0.9999999999999...  0.942420  0.934421
# 201  [0.9999997637145818, 0.9999968581938405, 0.999...  0.976880  0.992345
# ..                                                 ...       ...       ...
# 236  [0.9076016465636854, 0.8084075692507655, 0.694...  0.957939  0.812470
# 235  [0.9997194432406525, 0.9982620502630489, 0.993...  0.996167  0.940793
# 9    [0.9965518535316849, 0.9722958760024907, 0.882...  0.993266  0.994998
# 72   [0.9988199969437581, 0.9888191460360966, 0.944...  0.990254  0.938814
# 131  [0.9944652884638651, 0.966116311366993, 0.8808...  0.926384  0.989352
#
#            r2 difference nicer2  nicer  nicer3
# 153  0.937888 -13.899683   True   True    True
# 174  0.882148 -13.842468   True   True    True
# 80   0.979382 -11.318728   True   True    True
# 95   0.938420 -10.780980   True   True    True
# 201  0.984613  -9.467894   True   True    True
# ..        ...        ...    ...    ...     ...
# 236  0.885204   7.856104   True   True    True
# 235  0.968480   8.771168   True   True    True
# 9    0.994132   9.570861   True   True    True
# 72   0.964534  15.080958   True   True    True
# 131  0.957868  15.117787   True   True    True
#
# [85 rows x 25 columns]

# %%
# Out:
# 1.535848636688924

# %%
#Finding sigma and targets



########

plt.scatter(difff['difference'], difff['r2'])
plt.xlabel('difference')
plt.ylabel('R2')
plt.legend()
plt.title('scatter plot: R2/difference')

    
difff1 = difff.dropna()
difff1['nice']=difff1.apply(lambda x: (x['difference'])>kst.min()*sigma2+np.mean(difff['diff_control']), axis=1)
difff1['nice2']=difff1.apply(lambda x: (x['difference'])<np.mean(difff['diff_control'])-kst.min()*sigma2, axis=1)
difff2=difff1[difff1['nice']] 
difff3=difff1[difff1['nice2']] 
difff1 = pd.concat([difff2, difff3])                                                       
difff1 = difff1.sort_values(['r2'])
difff1 = difff1.reset_index(drop=True)
plt.scatter(difff1['difference'], difff1['r2'],label= f'number of proteins = {len(difff1)}', color = 'red')
plt.xlabel('difference')
plt.ylabel('R2')
plt.legend()
plt.title('scatter plot: R2/difference')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Plot solubility curves for targets

# #########
# #########

difff = difff.dropna()
difff1['nice']=difff1.apply(lambda x: (x['difference'])>kst.min()*sigma2+np.mean(difff['diff_control']), axis=1)
difff1['nice2']=difff1.apply(lambda x: (x['difference'])<np.mean(difff['diff_control'])-kst.min()*sigma2, axis=1)
difff2=difff1[difff1['nice']] 
difff3=difff1[difff1['nice2']] 
difff1 = pd.concat([difff2, difff3])
difff77 = pd.concat([difff2, difff3]) 
difff1['nice2']=difff1.apply(lambda x: abs(round(x['k'],1))>=0.5, axis=1)
difff1=difff1[difff1['nice2']]
difff1 = difff1.sort_values(['r2'])
difff1 = difff1.reset_index(drop=True)
plt.scatter(difff1['difference'], difff1['r2'], label= f'number of proteins = {len(difff1)}', color='red')
plt.xlabel('difference')
plt.ylabel('R2')
plt.legend()
plt.title('scatter plot: R2/difference')

plt.show()         

#########
#########
difff1=difff1.sort_values(['difference'])
difff1 = difff1.reset_index(drop=True)

for i in range(len(difff1)):
        plt.figure(figsize=(15,3))
        plt.plot(np.arange(310, 340, 0.01), func(np.arange(310, 340, 0.01), difff1['a'][i], difff1['b'][i]), color = 'b', 
                 alpha=0.5, label = f"k = {round(difff1['k'][i],2)}, t = {round(difff1['t'][i],2)}")
        plt.plot(np.arange(310, 340, 0.01), 
                 func_new(np.arange(310, 340, 0.01), difff1['l'][i], difff1['t'][i], difff1['k'][i], difff1['a'][i], difff1['b'][i]), 
                 color='orange', 
                 alpha=0.5)
        plt.scatter(difff1['x_val'][i], difff1['y_val_K'][i],color='b', alpha=0.5)
        plt.scatter(difff1['x_val'][i], difff1['y_val_T'][i],color='orange', alpha=0.5)
        plt.hlines(0, 308, 343, color='orange', linestyles='--')
        plt.hlines(1, 308, 343, color='orange', linestyles='--')
        plt.hlines(0.5, 308, 343, color='orange', linestyles='--')
        plt.xlabel('Temperature, ℃',fontsize=19)
        plt.legend(fontsize=19)                                                       # строю графики этих белков
        plt.title(difff1['dbname'][i],fontsize=19)
        plt.ylabel('FC normalized to 0:1',fontsize=19)
        plt.xticks(fontsize=19)  
        plt.yticks(fontsize=19)  
        plt.show()

# %%
#END OF NEW FORMULA

# %%
# START OF OLD FORMULA

# %%
#Approximating solubility curves

names=[]
coefsT = pd.DataFrame(columns=[ 'a', 'b'])
coefsK = pd.DataFrame(columns=[ 'a', 'b'])
norm_flag = 1

for dbname in list(resdict.keys()):
        all_y = defaultdict(list)
        all_y2 = defaultdict(list)
        all_x = defaultdict(list)
        all_x2 = defaultdict(list)                                                      

        y_val_max = 0
        y_val_min = 0

        for lbl, yval, yval2 in zip(lbls2, resdict[dbname], resdict2[dbname]):

     

            sample = ('K' if 'K' in lbl else 'T')
            timing = float(lbl.replace('T', '').replace('K', '').replace('C', ''))

            all_x[sample].append(timing+273)
            all_y[sample].append(yval)

            if y_val_max < yval:
                y_val_max = yval
            if y_val_min > yval:
                y_val_min = yval


            if yval2 != 0:
                all_x2[sample].append(timing+273)
                all_y2[sample].append(yval2)

        if 1:
            
            for sample in ['T']:
                loh1 = (2**(np.array(all_y[sample])))
                t = loh1-loh1[-1] 
                y = t/t[0]
                

                        
                try:
                    popt, pcov = optimize.curve_fit(func, np.array(all_x[sample]), y, p0=[200, 330], bounds = ([0, 298], [600, 350]), method='trf') 
                    perr = np.sqrt(np.diag(pcov))
                    perr1 = np.sqrt(np.power(perr[0],2)+np.power(perr[1], 2))# аппроксимация и добавление в датафрейм по treatment
                    coefsT=coefsT.append({'dbname': dbname, 'a':popt[0], 'b':popt[1],'y_val':y, 'y_val_without': loh1, 
                                          'perr_a': perr[0], 'perr_b': perr[1]}, ignore_index=True)
                except:
                     pass
                
                
            for sample in ['K']:
                
                l2 = (2**(np.array(all_y[sample])))                 
                t1 = l2-l2[-1]  
                y1 = t1/t1[0]

                try:
                    popt2, pcov2 = optimize.curve_fit(func, np.array(all_x[sample]), y1, p0=[200, 330], bounds = ([0, 298], [600, 350]), method='trf')
                    perr2 = np.sqrt(np.diag(pcov2))
                    perr22 = np.sqrt(np.power(perr2[0],2)+np.power(perr2[1], 2))
                    coefsK=coefsK.append({'dbname': dbname, 'a':popt2[0], 'b':popt2[1],'y_val':y1, 'y_val_without': l2,
                                         'perr_a':perr2[0], 'perr_b':perr2[1]}, ignore_index=True)
                except:
                    pass

# %%
#Finding R^2

diff = coefsT.merge(coefsK, how='inner', on='dbname', suffixes=('_T', '_K'))

x_difT=[]
for i in range(len(diff)):
    x_timedT=[]
    for j in range(len(all_x[sample])):
        x_timedT.append(all_x[sample][j])
    x_difT.append(x_timedT)

#########
#########

qu_difT=[]
for i in range(len(diff)):
    qu_timedT=[]
    for j in range(len(all_x[sample])):
        qu_timedT.append(func(all_x[sample][j], diff['a_T'][i], diff['b_T'][i]))
    qu_difT.append(qu_timedT)
    
qu_difK=[]
for i in range(len(diff)):
    qu_timedK=[]
    for j in range(len(all_x[sample])):
        qu_timedK.append(func(all_x[sample][j], diff['a_K'][i], diff['b_K'][i]))     
    qu_difK.append(qu_timedK)
        
#########
#########

diff['x_val'] = x_difT
diff['func_val_T'] = qu_difT
diff['func_val_K'] = qu_difK

#########
#########

r2_T=[]
r2_K =[]

for i in range(len(diff)):
    r2_T.append(r2_score(list(diff['y_val_T'][i]), list(diff['func_val_T'][i])))
    r2_K.append(r2_score(list(diff['y_val_K'][i]), list(diff['func_val_K'][i])))

diff['r2_T'] = r2_T
diff['r2_K'] = r2_K
diff['r2'] = (diff['r2_T']+diff['r2_K'])/2

# ########
# ########

diff['difference'] = diff['b_T']-diff['b_K']
diff['perr_diff'] = np.sqrt(diff['perr_b_K']**2 + diff['perr_b_T']**2)


#########
#########


diff = diff.sort_values(['difference'])

diff['nicer2']=diff.apply(lambda x: x['r2_T']>0.8, axis=1)
diff['nicer']=diff.apply(lambda x: x['r2_K']>0.8, axis=1)
diff=diff[diff['nicer']]
diff=diff[diff['nicer2']]

# %%
kst = np.array([])
for k in np.arange(2.5, 5, 0.1):
    prob_outside = 2 * norm.sf(k)  
    expected_outliers = prob_outside * len(diff)
#     expected_outliers = prob_outside * 3000
    if expected_outliers<1:
        kst = np.append(kst, k)
    print(f"{k} sigma: {expected_outliers} выбросов")

# %%
#Finding sigma and targets
########
plt.scatter(diff['difference'], diff['r2'])
plt.xlabel('Difference')
plt.ylabel('R2')
plt.legend()
plt.title('scatter plot: R2/Difference')
    
diff1 = diff.dropna()
diff1['nice']=diff1.apply(lambda x: (x['difference'])>kst.min()*sigma2+np.mean(difff['diff_control']), axis=1)
diff1['nice2']=diff1.apply(lambda x: (x['difference'])<np.mean(difff['diff_control'])-kst.min()*sigma2, axis=1)
diff2=diff1[diff1['nice']] 
diff3=diff1[diff1['nice2']] 
diff1 = pd.concat([diff2, diff3])
diff1 = diff1.sort_values(['r2'])
diff1 = diff1.reset_index(drop=True)
plt.scatter(diff1['difference'], diff1['r2'], color = 'red')
plt.xlabel('Difference')
plt.ylabel('R2')
plt.legend()
plt.title('scatter plot: R2/Difference')
plt.show()

# %%
diff1 = diff.dropna()
diff1['nice']=diff1.apply(lambda x: (x['difference'])>kst.min()*sigma2+np.mean(difff['diff_control']), axis=1)
diff1['nice2']=diff1.apply(lambda x: (x['difference'])<np.mean(difff['diff_control'])-kst.min()*sigma2, axis=1)
diff2=diff1[diff1['nice']] 
diff3=diff1[diff1['nice2']] 
diff1 = pd.concat([diff2, diff3])
diff1 = diff1.sort_values(['r2'])
diff1 = diff1.reset_index(drop=True)
plt.scatter(diff1['difference'], diff1['r2'], label= f'number of proteins = {len(diff1)}', color='red')
plt.xlabel('Difference')
plt.ylabel('R2')
plt.legend()
plt.title('scatter plot: R2/Difference')

plt.show()         

#########
#########
diff1=diff1.sort_values(['difference'])
diff1 = diff1.reset_index(drop=True)

for i in range(len(diff1)):
        plt.figure(figsize=(15,3))
        plt.scatter(diff1['x_val'][i], diff1['y_val_T'][i],color='orange', alpha=0.5)
        plt.scatter(diff1['x_val'][i], diff1['y_val_K'][i],color='b', alpha=0.5)
        plt.plot(np.arange(310, 340, 0.01), func(np.arange(310, 340, 0.01), diff1['a_T'][i], diff1['b_T'][i]), color = 'orange',label = f"fit Treatment, R2= {round(diff1['r2'][i], 2)}", alpha=0.5)
        plt.plot(np.arange(310, 340, 0.01), func(np.arange(310, 340, 0.01), diff1['a_K'][i], diff1['b_K'][i]), color='b',label = f"fit Control, difference = {round(diff1['difference'][i], 2)}", alpha=0.5)
        plt.hlines(0, 310, 340, color='orange', linestyles='--')
        plt.hlines(1, 310, 340, color='orange', linestyles='--')
        plt.hlines(0.5, 310, 340, color='orange', linestyles='--')
        plt.xlabel('Temperature', fontsize=18)
        plt.legend(fontsize=18)
        plt.xticks(fontsize=18)
        plt.yticks(fontsize=18)
        plt.title(diff1['dbname'][i], fontsize=18)
        plt.ylabel('FC normalized to 0:1', fontsize=18)
        plt.show()

# %%
anderson(difff['difference'])

# %%
anderson(diff['difference'])

# %%
from matplotlib_venn import venn2

# %%
#Venn diagram for target for old and new formula

set1 = set(diff1['dbname'])
set2 = set(difff1['dbname'])

plt.figure(figsize=(8, 6))

venn = venn2([set1, set2], set_labels=('Old Formula', 'New Formula'))

venn.get_patch_by_id('10').set_color('skyblue')
venn.get_patch_by_id('01').set_color('lightcoral')
venn.get_patch_by_id('11').set_color('lightgreen')

for text in venn.set_labels:
    text.set_fontsize(14)
for text in venn.subset_labels:
    if text:  
        text.set_fontsize(16)

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2

set1 = set(diff1['dbname'])
set3 = set(difff77['dbname'])

plt.figure(figsize=(8, 6))

venn = venn2([set1, set3], set_labels=('Old Formula', 'New Formula'))

venn.get_patch_by_id('10').set_color('skyblue')
venn.get_patch_by_id('01').set_color('lightcoral')
venn.get_patch_by_id('11').set_color('lightgreen')

for text in venn.set_labels:
    text.set_fontsize(14)
for text in venn.subset_labels:
    if text:  
        text.set_fontsize(16)

plt.show()
